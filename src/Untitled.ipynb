# %%
import numpy as np
import pandas as pd
import seaborn as sb

# %%
print(pd.__version__)
# Out:
# 2.0.3

# %%
data = pd.read_csv('D:\Python\Project\Division_Wise_Operational_Physical_Performance_Results_for_the_Period_February_2022.csv')

# %%
data.head()
# Out:
#    Sl.No.                       Factor  Bengaluru Central  Ramanagara  \
# 0     1.0    Schedules(As on last day)              595.0      457.00
# 1     2.0  Fleet Held (As on last day)              733.0      494.00
# 2     3.0        Fleet Utilisation (%)               66.1       87.60
# 3     4.0         % off road  vehicles                5.8        3.40
# 4     5.0       Schedule kms (in lakh)               57.2       40.52
#
#    Tumkuru  Kolara  Chikkaballapura  Mysore City  Mysore Rural  Mandya  \
# 0   568.00  512.00           515.00       360.00        618.00  418.00
# 1   617.00  539.00           564.00       431.00        688.00  447.00
# 2    87.70   90.00            90.20        79.40         83.30   89.40
# 3     5.20    4.80             2.70         3.30          6.00    4.30
# 4    54.76   48.09            51.48        21.29         61.48   42.57
#
#    Chamarajanagar  Hassan  Chikkamagaluru  Mangaluru  Puttur  Davanagere  \
# ...

# %%
data.tail()
# Out:
#     Sl.No.                       Factor  Bengaluru Central  Ramanagara  \
# 9     10.0                   KMPL (HSD)               4.70        5.11
# 10    11.0           No.of Break  downs               7.00        8.00
# 11     NaN      Rate of BD per 10000 km               0.01        0.02
# 12    12.0             No. of Accidents               8.00        2.00
# 13     NaN  Rate of Accdt per 100000 km               0.13        0.05
#
#     Tumkuru  Kolara  Chikkaballapura  Mysore City  Mysore Rural  Mandya  \
# 9      5.32    5.28             5.40         4.53          4.93    5.17
# 10    13.00    6.00            10.00         7.00          9.00   11.00
# 11     0.02    0.01             0.02         0.03          0.01    0.03
# 12     2.00    5.00             1.00         1.00          6.00    1.00
# 13     0.04    0.10             0.02         0.05          0.10    0.03
#
#     Chamarajanagar  Hassan  Chikkamagaluru  Mangaluru  Puttur  Davanagere  \
# ...

# %%
data.shape
# Out:
# (34, 19)

# %%
data.describe()
# Out:
#           Sl.No.  Bengaluru Central   Ramanagara      Tumkuru       Kolara  \
# count  34.000000          23.000000    23.000000    23.000000    23.000000
# mean   17.500000        1178.216087   719.206522   792.145652   712.945652
# std     9.958246        1953.602747  1328.573125  1355.036492  1350.733755
# min     1.000000        -677.760000  -467.270000  -536.870000  -842.460000
# 25%     9.250000           5.900000     4.745000     4.835000     5.210000
# 50%    17.500000          73.600000    44.090000    62.690000    55.210000
# 75%    25.750000        2014.575000   940.815000  1256.510000  1056.635000
# max    34.000000        5451.300000  4419.400000  4178.700000  4523.300000
#
#        Chikkaballapura       Mysore       Mandya  Chamarajanagar       Hassan  \
# count        23.000000    23.000000    23.000000       23.000000    23.000000
# mean        777.169130  1092.825652   697.326522      776.991304   756.837826
# ...

# %%
data.columns
# Out:
# Index(['Sl.No.', 'Factor', 'Bengaluru Central', 'Ramanagara', 'Tumkuru',
#        'Kolara', 'Chikkaballapura', 'Mysore', 'Mandya', 'Chamarajanagar',
#        'Hassan', 'Chikkamagaluru', 'Mangaluru', 'Puttur', 'Davanagere',
#        'Shivamoga', 'Chitradurga', 'Kempegowda Bus Station', 'KSRTC'],
#       dtype='object')

# %%
#group by route_id
Grp=data.groupby('route_id')
print(Grp.size())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 2
#       1 #group by route_id
# ----> 2 Grp=data.groupby('route_id')
#       3 print(Grp.size())
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:8252, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8249     raise TypeError("You have to supply one of 'by' and 'level'")
#    8250 axis = self._get_axis_number(axis)
# -> 8252 return DataFrameGroupBy(
#    8253     obj=self,
#    8254     keys=by,
#    8255     axis=axis,
#    8256     level=level,
#    8257     as_index=as_index,
#    8258     sort=sort,
#    8259     group_keys=group_keys,
#    8260     observed=observed,
#    8261     dropna=dropna,
#    8262 )
#
# ...

# %%
for route_id,group in Grp:
    print(f"Route ID :{route_id}")
    print(group)
    print()

# %% [markdown]
# https://youtu.be/-o3AxdVcUtQ?t=606
