# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data1=pd.read_csv("D:\Python\Project\Feb2022.csv")
data1.T.head()
# Out:
#                                           0                            1   \
# Sl.No.                                   1.0                          2.0
# Factor             Schedules(As on last day)  Fleet Held (As on last day)
# Bengaluru Central                      595.0                        733.0
# Ramanagara                             457.0                        494.0
# Tumkuru                                568.0                        617.0
#
#                                       2                     3   \
# Sl.No.                               3.0                   4.0
# Factor             Fleet Utilisation (%)  % off road  vehicles
# Bengaluru Central                   66.1                   5.8
# Ramanagara                          87.6                   3.4
# Tumkuru                             87.7                   5.2
#
#                                        4                               5   \
# Sl.No.                                5.0                             6.0
# Factor             Schedule kms (in lakh)  Effective Kilometers (in lakh)
# Bengaluru Central                    57.2                           59.54
# Ramanagara                          40.52                           39.36
# Tumkuru                             54.76                           52.68
#
#                                              6                    7   \
# Sl.No.                                      7.0                  8.0
# Factor             Vehicle Utilisation (in kms)  Gross kms (in lakh)
# Bengaluru Central                         436.0                61.65
# Ramanagara                                325.0                40.53
# Tumkuru                                   349.0                54.05
#
#                                        8           9                   10  \
# Sl.No.                                9.0        10.0                11.0
# Factor             HSD consumed (in lakh)  KMPL (HSD)  No.of Break  downs
# Bengaluru Central                   13.11         4.7                 7.0
# Ramanagara                           7.94        5.11                 8.0
# Tumkuru                             10.15        5.32                13.0
#
#                                         11                12  \
# Sl.No.                                 NaN              12.0
# Factor             Rate of BD per 10000 km  No. of Accidents
# Bengaluru Central                     0.01               8.0
# Ramanagara                            0.02               2.0
# Tumkuru                               0.02               2.0
#
#                                             13
# Sl.No.                                     NaN
# Factor             Rate of Accdt per 100000 km
# Bengaluru Central                         0.13
# Ramanagara                                0.05
# Tumkuru                                   0.04

# %%
D1=data1.T
D1.columns=D1.iloc[1]
D1=D1[2:]
D1
col_to_keep=['Schedules','Fleet Held (As on last day)','Fleet Utilisation (%)','% off road  vehicles','Schedule kms (in lakh)', 'Effective Kilometers (in lakh)']
D1.drop(columns=[col for col in D1.columns if col not in col_to_keep],inplace=True)
#remove empty rows
D1.dropna(inplace=True)
D1
#adding a new column as city id
D1['City_Id'] = range(1, len(D1) + 1)
D1.columns
# Out:
# Index(['Fleet Held (As on last day)', 'Fleet Utilisation (%)',
#        '% off road  vehicles', 'Schedule kms (in lakh)',
#        'Effective Kilometers (in lakh)', 'City_Id'],
#       dtype='object', name='Factor')

# %%
#Effective passenger density
#effPassDensity=(('Fleet Utilisation(%)')*0.01)*('Fleet Held')

FleetUtilisation=D1['Fleet Utilisation (%)']*0.01
FleetHeldArray=D1['Fleet Held (As on last day)']
EffPassDensity=np.multiply(FleetUtilisation,FleetHeldArray)
D1['EffPassDensity']=EffPassDensity

# %%
D1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17 entries, Bengaluru Central to KSRTC
# Data columns (total 7 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Fleet Held (As on last day)     17 non-null     object
#  1   Fleet Utilisation (%)           17 non-null     object
#  2   % off road  vehicles            17 non-null     object
#  3   Schedule kms (in lakh)          17 non-null     object
#  4   Effective Kilometers (in lakh)  17 non-null     object
#  5   City_Id                         17 non-null     int64
#  6   EffPassDensity                  17 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.1+ KB

# %%
D1.head()
# Out:
# Factor            Fleet Held (As on last day) Fleet Utilisation (%)  \
# Bengaluru Central                       733.0                  66.1
# Ramanagara                              494.0                  87.6
# Tumkuru                                 617.0                  87.7
# Kolara                                  539.0                  90.0
# Chikkaballapura                         564.0                  90.2
#
# Factor            % off road  vehicles Schedule kms (in lakh)  \
# Bengaluru Central                  5.8                   57.2
# Ramanagara                         3.4                  40.52
# Tumkuru                            5.2                  54.76
# Kolara                             4.8                  48.09
# Chikkaballapura                    2.7                  51.48
#
# Factor            Effective Kilometers (in lakh)  City_Id EffPassDensity
# Bengaluru Central                          59.54        1        484.513
# Ramanagara                                 39.36        2        432.744
# Tumkuru                                    52.68        3        541.109
# Kolara                                     47.71        4          485.1
# Chikkaballapura                            51.06        5        508.728

# %%
D1.tail()
# Out:
# Factor      Fleet Held (As on last day) Fleet Utilisation (%)  \
# Puttur                            542.0                  87.2
# Davanagere                        358.0                  94.2
# Shivamoga                         352.0                  86.6
# Chitradurga                       303.0                  90.7
# KSRTC                            8219.0                  86.3
#
# Factor      % off road  vehicles Schedule kms (in lakh)  \
# Puttur                       4.2                  43.66
# Davanagere                   4.3                  32.77
# Shivamoga                    4.1                  31.74
# Chitradurga                  8.5                  28.74
# KSRTC                        4.9                 713.81
#
# Factor      Effective Kilometers (in lakh)  City_Id EffPassDensity
# Puttur                               42.48       13        472.624
# Davanagere                           32.96       14        337.236
# Shivamoga                            31.82       15        304.832
# Chitradurga                          27.42       16        274.821
# KSRTC                               702.05       17       7092.997

# %%
X=D1['City_Id']
Y=D1['Fleet Utilisation (%)']
plt.bar(X,Y)
plt.xlabel('City ID')
plt.ylabel('Fleet utilisation %')
plt.xticks(X)  # Set x-axis ticks to match city IDs
# Set y-axis range with a step of 10
plt.ylim(0, 100)  # Set the y-axis range from 0 to 100
plt.yticks(range(0, 101, 10))  # Set y-axis ticks with a step of 10
plt.grid(True)
plt.show()

# %%
D1
# Out:
# Factor            Fleet Held (As on last day) Fleet Utilisation (%)  \
# Bengaluru Central                       733.0                  66.1
# Ramanagara                              494.0                  87.6
# Tumkuru                                 617.0                  87.7
# Kolara                                  539.0                  90.0
# Chikkaballapura                         564.0                  90.2
# Mysore City                             431.0                  79.4
# Mysore Rural                            688.0                  83.3
# Mandya                                  447.0                  89.4
# Chamarajanagar                          509.0                  89.4
# Hassan                                  547.0                  93.1
# Chikkamagaluru                          526.0                  93.7
# Mangaluru                               569.0                  84.5
# Puttur                                  542.0                  87.2
# Davanagere                              358.0                  94.2
# Shivamoga                               352.0                  86.6
# Chitradurga                             303.0                  90.7
# KSRTC                                  8219.0                  86.3
#
# Factor            % off road  vehicles Schedule kms (in lakh)  \
# Bengaluru Central                  5.8                   57.2
# Ramanagara                         3.4                  40.52
# Tumkuru                            5.2                  54.76
# Kolara                             4.8                  48.09
# Chikkaballapura                    2.7                  51.48
# Mysore City                        3.3                  21.29
# Mysore Rural                       6.0                  61.48
# Mandya                             4.3                  42.57
# Chamarajanagar                     5.3                  45.05
# Hassan                             5.7                  52.77
# Chikkamagaluru                     3.8                  50.86
# Mangaluru                          6.5                  50.81
# Puttur                             4.2                  43.66
# Davanagere                         4.3                  32.77
# Shivamoga                          4.1                  31.74
# Chitradurga                        8.5                  28.74
# KSRTC                              4.9                 713.81
#
# Factor            Effective Kilometers (in lakh)  City_Id EffPassDensity
# Bengaluru Central                          59.54        1        484.513
# Ramanagara                                 39.36        2        432.744
# Tumkuru                                    52.68        3        541.109
# Kolara                                     47.71        4          485.1
# Chikkaballapura                            51.06        5        508.728
# Mysore City                                20.82        6        342.214
# Mysore Rural                               61.13        7        573.104
# Mandya                                     39.95        8        399.618
# Chamarajanagar                             43.72        9        455.046
# Hassan                                     51.09       10        509.257
# Chikkamagaluru                             49.92       11        492.862
# Mangaluru                                  50.38       12        480.805
# Puttur                                     42.48       13        472.624
# Davanagere                                 32.96       14        337.236
# Shivamoga                                  31.82       15        304.832
# Chitradurga                                27.42       16        274.821
# KSRTC                                     702.05       17       7092.997

# %%
X=D1['City_Id']
Y=D1['EffPassDensity']
sns.barplot(x=X,y=Y,orient='v')
plt.xticks(X)
plt.ylim(0, 1000)  # Set the y-axis range from 0 to 100
plt.yticks(range(0, 1001, 50))
plt.show()

# %% [markdown]
# ### Descriptive Statistic Analysis
# Mean of EffectivePassengerDensity = meanEPD

# %%
meanEPD=np.mean(D1['EffPassDensity'])
print('Mean of Effective Passenger Density:',meanEPD)

D1['EffPassDensity'].values
# Out:
# Mean of Effective Passenger Density: 834.5652941176471
# array([484.5129999999999, 432.744, 541.109, 485.1, 508.728, 342.214,
#        573.1039999999999, 399.61800000000005, 455.04600000000005,
#        509.25699999999995, 492.862, 480.805, 472.624, 337.23600000000005,
#        304.832, 274.821, 7092.997], dtype=object)

# %%
std_by_city = D1['EffPassDensity'].std()
variance=std_by_city**2
print('variance:',variance)
print('Standard deviation:',std_by_city)
# Out:
# variance: 2608147.7934505953
# Standard deviation: 1614.9760968666365

# %%
#calculate the (X-mean) for each city and it as a column
XdiffMean=D1['EffPassDensity'][:15].values-meanEPD


NewD1={
    'City Id':D1['City_Id'][:15].values,
    'EffPassDensity':D1['EffPassDensity'][:15].values,
    'Mean Variations':XdiffMean
}
NewD1=pd.DataFrame(NewD1)
NewD1
# Out:
#     City Id EffPassDensity Mean Variations
# 0         1        484.513     -350.052294
# 1         2        432.744     -401.821294
# 2         3        541.109     -293.456294
# 3         4          485.1     -349.465294
# 4         5        508.728     -325.837294
# 5         6        342.214     -492.351294
# 6         7        573.104     -261.461294
# 7         8        399.618     -434.947294
# 8         9        455.046     -379.519294
# 9        10        509.257     -325.308294
# 10       11        492.862     -341.703294
# 11       12        480.805     -353.760294
# 12       13        472.624     -361.941294
# 13       14        337.236     -497.329294
# 14       15        304.832     -529.733294

# %%
sns.barplot(x=NewD1['City Id'],y=NewD1['Mean Variations'],palette='pastel')
plt.xticks(X)
plt.ylim(0, 1000)  # Set the y-axis range from 0 to 100
plt.yticks(range(-1000, 1001, 100))
plt.show()

# %%
import statistics as stats
from scipy.stats import norm 
dfmean = np.mean(D1['EffPassDensity'])
sd = np.std(D1['EffPassDensity'])
sorted_data = D1['EffPassDensity'].sort_values()
X=np.linspace(D1['EffPassDensity'].min(),D1['EffPassDensity'].max(),100)
pdf_values = norm.pdf(X, dfmean, sd)
sns.kdeplot(pdf_values, shade = True)
# Out:
# C:\Users\abhib\AppData\Local\Temp\ipykernel_10484\4241719585.py:8: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(pdf_values, shade = True)
# <Axes: ylabel='Density'>

# %%
Stats = D1.describe(include='all')
cols = Stats.index.tolist()
Stats
# Out:
# Factor  Fleet Held (As on last day)  Fleet Utilisation (%)  \
# count                          17.0                   17.0
# unique                         17.0                   16.0
# top                           733.0                   89.4
# freq                            1.0                    2.0
# mean                            NaN                    NaN
# std                             NaN                    NaN
# min                             NaN                    NaN
# 25%                             NaN                    NaN
# 50%                             NaN                    NaN
# 75%                             NaN                    NaN
# max                             NaN                    NaN
#
# Factor  % off road  vehicles  Schedule kms (in lakh)  \
# count                   17.0                    17.0
# unique                  16.0                    17.0
# top                      4.3                    57.2
# freq                     2.0                     1.0
# mean                     NaN                     NaN
# std                      NaN                     NaN
# min                      NaN                     NaN
# 25%                      NaN                     NaN
# 50%                      NaN                     NaN
# 75%                      NaN                     NaN
# max                      NaN                     NaN
#
# Factor  Effective Kilometers (in lakh)    City_Id  EffPassDensity
# count                            17.00  17.000000          17.000
# unique                           17.00        NaN          17.000
# top                              59.54        NaN         484.513
# freq                              1.00        NaN           1.000
# mean                               NaN   9.000000             NaN
# std                                NaN   5.049752             NaN
# min                                NaN   1.000000             NaN
# 25%                                NaN   5.000000             NaN
# 50%                                NaN   9.000000             NaN
# 75%                                NaN  13.000000             NaN
# max                                NaN  17.000000             NaN

# %%
for j in cols:
    for i in Stats.columns:
        if j == 'mean' and pd.isna(Stats.loc[j, i]):
            Stats.loc[j, i] = D1[i].mean()
        elif j == 'std' and pd.isna(Stats.loc[j, i]):
            Stats.loc[j, i] = D1[i].std()
        elif j == 'min' and pd.isna(Stats.loc[j, i]):
            Stats.loc[j, i] = D1[i].min()
        elif j == 'max' and pd.isna(Stats.loc[j, i]):
            Stats.loc[j, i] = D1[i].max()
        elif j == '25%' and pd.isna(Stats.loc[j, i]):
            Stats.loc[j, i] = D1[i].quantile(q=0.25)
        elif j == '50%' and pd.isna(Stats.loc[j, i]):
            Stats.loc[j, i] = D1[i].quantile(q=0.50)
        elif j == '75%':
            Stats.loc[j, i] = D1[i].quantile(q=0.75)

Stats
# Out:
# Factor  Fleet Held (As on last day)  Fleet Utilisation (%)  \
# count                     17.000000              17.000000
# unique                    17.000000              16.000000
# top                      733.000000              89.400000
# freq                       1.000000               2.000000
# mean                     966.941176              87.023529
# std                     1872.219521               6.588013
# min                      303.000000              66.100000
# 25%                      447.000000              86.300000
# 50%                      539.000000              87.700000
# 75%                      569.000000              90.200000
# max                     8219.000000              94.200000
#
# Factor  % off road  vehicles  Schedule kms (in lakh)  \
# count              17.000000               17.000000
# unique             16.000000               17.000000
# top                 4.300000               57.200000
# freq                2.000000                1.000000
# mean                4.870588               83.976471
# std                 1.394975              162.664614
# min                 2.700000               21.290000
# 25%                 4.100000               40.520000
# 50%                 4.800000               48.090000
# 75%                 5.700000               52.770000
# max                 8.500000              713.810000
#
# Factor  Effective Kilometers (in lakh)    City_Id  EffPassDensity
# count                        17.000000  17.000000       17.000000
# unique                       17.000000        NaN       17.000000
# top                          59.540000        NaN      484.513000
# freq                          1.000000        NaN        1.000000
# mean                         82.593529   9.000000      834.565294
# std                         160.006179   5.049752     1614.976097
# min                          20.820000   1.000000      274.821000
# 25%                          39.360000   5.000000      399.618000
# 50%                          47.710000   9.000000      480.805000
# 75%                          51.090000  13.000000      508.728000
# max                         702.050000  17.000000     7092.997000

# %%
from scipy.stats import expon

# Given data
data = D1['EffPassDensity'][0:15].to_numpy()
# Calculate lambda for the exponential distribution
lambda_param = 1 / data.mean()
print(type(data[0]))
myData=data.astype('float64')


# Generate x values for the plot
x_range = np.linspace(min(data), max(data), 15)
Data=-lambda_param*x_range
myData=-lambda_param*myData
# Calculate the exponential PDF values
pdf_values = np.exp(Data)
myPdf=np.exp(myData)

pdf_values=lambda_param*pdf_values
myPdf=lambda_param*myPdf

# Plot the exponential PDF curve
plt.plot(x_range, pdf_values, color='red', label='Exponential PDF')
plt.plot(x_range, myPdf, color='blue', label='my PDF')
plt.xlabel('X')
plt.ylabel('Probability Density')
plt.title('Fitting Data to Exponential Distribution')
plt.legend()
plt.grid(True)
plt.show()

print(pdf_values,myPdf)
# Out:
# <class 'float'>
# [0.00112496 0.00107853 0.00103402 0.00099135 0.00095043 0.00091121
#  0.0008736  0.00083754 0.00080298 0.00076984 0.00073807 0.00070761
#  0.0006784  0.0006504  0.00062356] [0.00075771 0.00084909 0.00066902 0.00075673 0.00071841 0.00103617
#  0.00062356 0.00091326 0.00080844 0.00071757 0.00074392 0.00076391
#  0.00077778 0.00104757 0.00112496]

# %%
import statistics as stats
from scipy.stats import norm 
import scipy.stats
Xfactor=D1['EffPassDensity'][:15].values
Yfactor=D1['Effective Kilometers (in lakh)'][:15].values
print(Xfactor.size,Yfactor.size)
R=scipy.stats.pearsonr(Xfactor,Yfactor)
print("Coefficient of correlation between EffPassDensity & Effective Kilometers (in lakh):",R[0])
# Out:
# 15 15
# Coefficient of correlation between EffPassDensity & Effective Kilometers (in lakh): 0.8996094517558868

# %%
data = {
    'Xfactor': D1['EffPassDensity'][:15].values,
    'Yfactor': D1['Effective Kilometers (in lakh)'][:15].values
}
Df=pd.DataFrame(data)
corrMatrix=Df.corr()
corrMatrix
Df['Xfactor'] = pd.to_numeric(Df['Xfactor'])
Df['Yfactor'] = pd.to_numeric(Df['Yfactor'])

subset_df=Df[:15]
slope, intercept = np.polyfit(subset_df['Xfactor'], subset_df['Yfactor'], 1)
regression_line = slope * subset_df['Xfactor'] + intercept

plt.figure(figsize=(6, 4))
plt.scatter(Df['Xfactor'][:15], Df['Yfactor'][:15], color='blue', alpha=0.5)
plt.plot(subset_df['Xfactor'], regression_line, color='red', label='Regression Line')
plt.xlabel('EffPassDensity')
plt.ylabel('Effective kilometers(in lakh)')
plt.title('Scatter Plot of Xfactor vs Yfactor')
plt.grid(True)

plt.show()


plt.figure(figsize=(8, 6))
sns.heatmap(corrMatrix, annot=True,center=0,linecolor='blue')
plt.title('Correlation Heatmap')
plt.show()
