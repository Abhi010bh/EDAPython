# %%
import pandas as pd

# %%
data1=pd.read_csv("D:\Python\Project\April2022.csv")
data2=pd.read_csv("D:\Python\Project\Feb2022.csv")
data3=pd.read_csv("D:\Python\Project\June2022.csv")
data4=pd.read_csv("D:\Python\Project\May2022.csv")

DATA=pd.concat([data1,data2])

print(DATA.head())
print()
print(data1.head())
# Out:
#    Sl.No.                Factor  Bengaluru Central  Ramanagara  Tumkuru  \
# 0     1.0  Physical performance                NaN         NaN      NaN
# 1     2.0             Schedules              621.0       457.0    581.0
# 2     3.0      (As on last day)                NaN         NaN      NaN
# 3     4.0            Fleet Held              733.0       491.0    614.0
# 4     5.0      (As on last day)                NaN         NaN      NaN
#
#    Kolara  Chikkaballapura  Mysore  Mandya  Chamarajanagar  ...  \
# 0     NaN              NaN     NaN     NaN             NaN  ...
# 1   504.0            521.0   977.0   423.0           465.0  ...
# 2     NaN              NaN     NaN     NaN             NaN  ...
# 3   538.0            574.0  1091.0   447.0           509.0  ...
# 4     NaN              NaN     NaN     NaN             NaN  ...
#
#    Chikkamagaluru  Mangaluru  Puttur  Davanagere  Shivamoga  Chitradurga  \
# ...

# %%
D1=data1.T
D1.columns=D1.iloc[1]
D1=D1[2:]
for i in D1.columns:
    print(i)
col_to_keep=['Schedules','(As on last day)','Fleet Held','(As on last day)','Fleet Utilisation (%)','Financial performance']
D1.drop(columns=[col for col in D1.columns if col not in col_to_keep],inplace=True)
D1
# Out:
# Physical performance
# Schedules
# (As on last day)
# Fleet Held
# (As on last day)
# Fleet Utilisation (%)
# % off road  vehicles
# Schedule kms (in lakh)
# Effective Kilometers (in lakh)
# Vehicle Utilisation (in kms)
# Gross kms (in lakh)
# High speed diesel  consumed (in lakh)
# Kilometer per liter (High speed diesel )
# No.of Break  downs
# Rate of Break down per 10000 km
# No. of Accidents
# Rate of Accident per 100000 km
# Financial performance
# Traffic Revenue
# (Rs. in lakh)
# Other Revenue
# (Rs. in lakh)
# Gross Revenue
# (Rs. in lakh)
# Cost of Operation
# (Rs. in lakh)
# Margin  (Rs. in lakh)
# a. On traffic revenue
# b. on gross revenue
# Earnings Per Kilo Metre (in paise)
# (On traffic revenue)
# Earnings Per Kilo Metre (in paise)
# (On Gross revenue)
# COST  PER kilo meter (in paise)
# Factor                 Schedules (As on last day) Fleet Held (As on last day)  \
# Bengaluru Central          621.0              NaN      733.0              NaN
# ...

# %%
print(data1.describe())
# Out:
#           Sl.No.  Bengaluru Central   Ramanagara      Tumkuru       Kolara  \
# count  34.000000          23.000000    23.000000    23.000000    23.000000
# mean   17.500000        1177.930870   690.750435   768.154348   708.359565
# std     9.958246        1950.477745  1287.151011  1356.364405  1326.003996
# min     1.000000        -667.240000  -487.380000  -676.950000  -805.080000
# 25%     9.250000           4.310000     5.055000     4.345000     5.625000
# 50%    17.500000          75.610000    43.560000    61.800000    53.030000
# 75%    25.750000        2026.795000   899.475000  1206.585000  1014.075000
# max    34.000000        5433.800000  4343.500000  4306.700000  4455.900000
#
#        Chikkaballapura       Mysore       Mandya  Chamarajanagar       Hassan  \
# count        23.000000    23.000000    23.000000       23.000000    23.000000
# mean        758.231739  1022.386957   670.703043      746.594348   759.866522
# ...
